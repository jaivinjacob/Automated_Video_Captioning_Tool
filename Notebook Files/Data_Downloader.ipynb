# %%
cd C:\Users\jaivi\Downloads\MovieData
# Out:
# C:\Users\jaivi\Downloads\MovieData

# %%
import pandas as pd

# Path to your Parquet file
file_path = '0000.parquet'

# Read the Parquet file
df = pd.read_parquet(file_path, engine='pyarrow')

# Display the DataFrame
print(df)
# Out:
#             videoid                                         contentUrl  \
# 0          21179416  https://ak.picdn.net/shutterstock/videos/21179...
# 1           5629184  https://ak.picdn.net/shutterstock/videos/56291...
# 2        1063125190  https://ak.picdn.net/shutterstock/videos/10631...
# 3        1039695998  https://ak.picdn.net/shutterstock/videos/10396...
# 4           9607838  https://ak.picdn.net/shutterstock/videos/96078...
# ...             ...                                                ...
# 1792495  1021499794  https://ak.picdn.net/shutterstock/videos/10214...
# 1792496  1033753421  https://ak.picdn.net/shutterstock/videos/10337...
# 1792497  1017392800  https://ak.picdn.net/shutterstock/videos/10173...
# 1792498  1032128717  https://ak.picdn.net/shutterstock/videos/10321...
# 1792499  1010553644  https://ak.picdn.net/shutterstock/videos/10105...
#
#             duration       page_dir  \
# 0        PT00H00M11S  006001_006050
# 1        PT00H00M29S  071501_071550
# 2        PT00H00M07S  133701_133750
# 3        PT00H00M08S  011901_011950
# 4        PT00H00M32S  121551_121600
# ...              ...            ...
# 1792495  PT00H00M13S  129301_129350
# 1792496  PT00H00M17S  004201_004250
# 1792497  PT00H00M12S  092501_092550
# 1792498  PT00H00M10S  189151_189200
# 1792499  PT00H00M18S  179351_179400
#
#                                                       name
# 0                                Aerial shot winter forest
# 1        Senior couple looking through binoculars on sa...
# 2        A beautiful cookie with oranges lies on a gree...
# 3        Japanese highrise office skyscrapers tokyo square
# 4        Zrenjanin,serbia march 21 2015: fans watching ...
# ...                                                    ...
# 1792495  Jakarta, indonesia - dec 14, 2018 : the aerial...
# 1792496  Fitness man athlete training using intense car...
# 1792497  Man driving a forklift through a warehouse in ...
# 1792498           Abstract background with beautiful color
# 1792499  Fresh vegetables falling in water with bubbles...
#
# [1792500 rows x 5 columns]

# %%
import os
import requests
import csv


def download_videos(df, download_folder="videos_1000", max_rows=1000):
  """
  Downloads videos from URLs in a dataframe and creates a new CSV file, skipping videos with encoding errors.

  Args:
    df: The pandas dataframe containing video data.
    download_folder: The folder where downloaded videos will be saved. (default: "videos_1000")
    max_rows: The maximum number of rows to process. (default: 1000)
  """
  # Create download folder if it doesn't exist
  os.makedirs(download_folder, exist_ok=True)

  # Open new CSV file for writing
  with open("downloaded_videos.csv", "w",encoding = "utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["video_id", "video_path", "description"])

    # Iterate over a maximum of 1000 rows
    for index, row in df.iloc[:max_rows].iterrows():
      video_id = row["videoid"]
      video_url = row["contentUrl"]
      video_name = row["name"]

      # Generate filename with extension
      filename = f"{video_id}.mp4"  # Adjust extension if needed based on video type
      video_path = os.path.join(download_folder, filename)

      # Check if video file already exists
      if not os.path.isfile(video_path):
        try:
          # Download video
          response = requests.get(video_url, stream=True)
          if response.status_code == 200:
            with open(video_path, 'wb') as f:
              for chunk in response.iter_content(1024):
                f.write(chunk)
            print(f"Downloaded video: {video_id}")
          else:
            print(f"Failed to download video: {video_id} - Status Code: {response.status_code}")
        except Exception as e:
          print(f"Error downloading video: {video_id} - {e}")
      else:
        print(f"Skipping video: {video_id} (already exists)")

      try:
        # Encode and decode video name for CSV (handle potential errors)
        decoded_name = video_name.encode('utf-8').decode('latin-1')  # Assuming cp1252 is your current encoding
      except UnicodeEncodeError:
        print(f"Skipping video name encoding for video: {video_id} (potential encoding issue)")
        decoded_name = "Encoding Error"  # Use a placeholder for videos with encoding errors

      # Write data to CSV regardless of download or encoding status
      writer.writerow([video_id, video_path, decoded_name])

# Example usage (assuming your dataframe is named 'df')
download_videos(df)
# Out:
# Skipping video: 21179416 (already exists)
# Skipping video: 5629184 (already exists)
# Skipping video: 1063125190 (already exists)
# Skipping video: 1039695998 (already exists)
# Skipping video: 9607838 (already exists)
# Skipping video: 21157780 (already exists)
# Skipping video: 1016180245 (already exists)
# Skipping video: 19107358 (already exists)
# Skipping video: 1036840850 (already exists)
# Skipping video: 13347398 (already exists)
# Skipping video: 1026436784 (already exists)
# Skipping video: 9000853 (already exists)
# Skipping video: 1047392872 (already exists)
# Skipping video: 30436075 (already exists)
# Skipping video: 6248114 (already exists)
# Skipping video: 1041349231 (already exists)
# Skipping video: 22517557 (already exists)
# Skipping video: 10807676 (already exists)
# Skipping video: 3280088 (already exists)
# Skipping video: 1022584264 (already exists)
# Skipping video: 1032669275 (already exists)
# Skipping video: 1016442058 (already exists)
# Skipping video: 5770451 (already exists)
# Skipping video: 18053848 (already exists)
# Skipping video: 6761770 (already exists)
# Skipping video: 1017176851 (already exists)
# Skipping video: 1013788766 (already exists)
# Skipping video: 1031365682 (already exists)
# Skipping video: 1014113975 (already exists)
# Skipping video: 1008782555 (already exists)
# Skipping video: 25534 (already exists)
# Skipping video: 1062211597 (already exists)
# Skipping video: 1023956678 (already exists)
# Skipping video: 1028805368 (already exists)
# Skipping video: 1051729318 (already exists)
# Skipping video: 1018923682 (already exists)
# Skipping video: 1052565473 (already exists)
# Skipping video: 1008747824 (already exists)
# Skipping video: 1040274026 (already exists)
# Skipping video: 17643496 (already exists)
# Skipping video: 33874699 (already exists)
# Skipping video: 12104420 (already exists)
# Skipping video: 1024408280 (already exists)
# Skipping video: 17468389 (already exists)
# Skipping video: 4406207 (already exists)
# Skipping video: 1013982629 (already exists)
# Skipping video: 34482013 (already exists)
# Skipping video: 29680303 (already exists)
# Skipping video: 1027734908 (already exists)
# Skipping video: 1048045609 (already exists)
# Skipping video: 1021208680 (already exists)
# Skipping video: 1038686987 (already exists)
# Skipping video: 29269396 (already exists)
# Skipping video: 22430842 (already exists)
# Skipping video: 1058564860 (already exists)
# Skipping video: 1019176354 (already exists)
# Skipping video: 1013766260 (already exists)
# Skipping video: 1036128737 (already exists)
# Skipping video: 13087850 (already exists)
# Skipping video: 1013905295 (already exists)
# Skipping video: 26026529 (already exists)
# Skipping video: 13339322 (already exists)
# Skipping video: 20246539 (already exists)
# Skipping video: 1015408639 (already exists)
# Skipping video: 2048828 (already exists)
# Skipping video: 35036167 (already exists)
# Skipping video: 2424545 (already exists)
# Skipping video: 1026725324 (already exists)
# Skipping video: 10830587 (already exists)
# Skipping video: 8309845 (already exists)
# Skipping video: 1047982123 (already exists)
# Skipping video: 30932815 (already exists)
# Skipping video: 1047870070 (already exists)
# Skipping video: 1845259 (already exists)
# Skipping video: 1031551415 (already exists)
# Skipping video: 23950981 (already exists)
# Skipping video: 31200691 (already exists)
# Skipping video: 1024839509 (already exists)
# Skipping video: 1048902214 (already exists)
# Skipping video: 1027910549 (already exists)
# Skipping video: 1057406263 (already exists)
# Skipping video: 11142482 (already exists)
# Skipping video: 19750504 (already exists)
# Skipping video: 1031607416 (already exists)
# Skipping video: 31730842 (already exists)
# Skipping video: 6149330 (already exists)
# Skipping video: 30187849 (already exists)
# Skipping video: 1024884527 (already exists)
# Skipping video: 1034180354 (already exists)
# Skipping video: 1019128234 (already exists)
# Skipping video: 6698615 (already exists)
# Skipping video: 1039387817 (already exists)
# Skipping video: 22356913 (already exists)
# Skipping video: 1030702778 (already exists)
# Skipping video: 1021798312 (already exists)
# Skipping video: 9005344 (already exists)
# Skipping video: 31040395 (already exists)
# Skipping video: 24421982 (already exists)
# Skipping video: 16522138 (already exists)
# Skipping video: 1036347950 (already exists)
# Skipping video: 1016601517 (already exists)
# Skipping video: 14394850 (already exists)
# Skipping video: 1034615321 (already exists)
# Skipping video: 1016732020 (already exists)
# Skipping video: 23784046 (already exists)
# Skipping video: 19241164 (already exists)
# Skipping video: 6595001 (already exists)
# Skipping video: 29069773 (already exists)
# Skipping video: 1040858936 (already exists)
# Skipping video: 1059607796 (already exists)
# Skipping video: 1044710635 (already exists)
# Skipping video: 17209774 (already exists)
# Skipping video: 9256628 (already exists)
# Skipping video: 29957920 (already exists)
# Skipping video: 7711219 (already exists)
# Skipping video: 3524387 (already exists)
# Skipping video: 1033745003 (already exists)
# Skipping video: 17891965 (already exists)
# Skipping video: 1017799882 (already exists)
# Skipping video: 15005677 (already exists)
# Skipping video: 1066968916 (already exists)
# Skipping video: 1060377596 (already exists)
# Skipping video: 1049442178 (already exists)
# Skipping video: 34180123 (already exists)
# Skipping video: 5074733 (already exists)
# Skipping video: 1019981971 (already exists)
# Skipping video: 1052316892 (already exists)
# Skipping video: 1029540947 (already exists)
# Skipping video: 18940043 (already exists)
# Skipping video: 1007094259 (already exists)
# Skipping video: 1044451144 (already exists)
# Skipping video: 32036101 (already exists)
# Skipping video: 31083397 (already exists)
# Skipping video: 1055092781 (already exists)
# Skipping video: 18030040 (already exists)
# Skipping video: 1057630129 (already exists)
# Skipping video: 1012444721 (already exists)
# Skipping video: 1026590378 (already exists)
# Skipping video: 1012354937 (already exists)
# Skipping video: 88843 (already exists)
# Skipping video: 1009379528 (already exists)
# Skipping video: 1056834017 (already exists)
# Skipping video: 1047859579 (already exists)
# Skipping video: 1011324077 (already exists)
# Skipping video: 1013746241 (already exists)
# Downloaded video: 1064456023
# Downloaded video: 1524320
# Downloaded video: 9019765
# Downloaded video: 3843581
# Downloaded video: 1028863754
# Downloaded video: 1031548169
# Downloaded video: 1032497327
# Downloaded video: 1035493928
# Downloaded video: 16712080
# Downloaded video: 4525166
# Downloaded video: 2933461
# Downloaded video: 1049331448
# Downloaded video: 1033922921
# Downloaded video: 1043817322
# Downloaded video: 1020381967
# Downloaded video: 1013748203
# Downloaded video: 28934869
# Downloaded video: 25046870
# Downloaded video: 32767318
# Downloaded video: 22608862
# Downloaded video: 1016142634
# Downloaded video: 6115853
# Downloaded video: 4104532
# Downloaded video: 1007624674
# Downloaded video: 18856901
# Downloaded video: 28074892
# Downloaded video: 17358745
# Downloaded video: 25972655
# Downloaded video: 4835363
# Downloaded video: 1028213024
# Downloaded video: 1014042872
# Downloaded video: 26767192
# Downloaded video: 20185852
# Downloaded video: 1020141418
# Downloaded video: 4985153
# Downloaded video: 1027506080
# Downloaded video: 1013341718
# Downloaded video: 1029691757
# Downloaded video: 1064705041
# Downloaded video: 1035186095
# Downloaded video: 1023688129
# Downloaded video: 1048879660
# Downloaded video: 32921860
# Downloaded video: 1063879180
# Downloaded video: 1054659131
# Downloaded video: 1023943766
# Downloaded video: 31503331
# Downloaded video: 1030478381
# Downloaded video: 1032419327
# Downloaded video: 1012925786
# Downloaded video: 1043574166
# Downloaded video: 1201834
# Downloaded video: 20585704
# Downloaded video: 1007474398
# Downloaded video: 1010949941
# Downloaded video: 15559042
# Downloaded video: 28109266
# Downloaded video: 21345625
# Downloaded video: 19481974
# Downloaded video: 13096670
# Downloaded video: 1026177167
# Downloaded video: 18328900
# Downloaded video: 1020275404
# Downloaded video: 23820001
# Downloaded video: 1049914171
# Downloaded video: 4529960
# Downloaded video: 25137896
# Downloaded video: 14020100
# Downloaded video: 12312911
# Downloaded video: 12982496
# Downloaded video: 3806714
# Downloaded video: 1047974278
# Downloaded video: 34213
# Downloaded video: 25839158
# Downloaded video: 15365350
# Downloaded video: 1040641403
# Downloaded video: 17524786
# Downloaded video: 1016056618
# Downloaded video: 21687451
# Downloaded video: 6260558
# Downloaded video: 32789644
# Downloaded video: 16009753
# Downloaded video: 1034894669

# %%
import pandas as pd

def process_downloaded_videos(csv_file="downloaded_videos.csv"):
  """
  Reads downloaded video information from a CSV file and prints the first 10 rows.

  Args:
    csv_file: The path to the CSV file containing video data. (default: "downloaded_videos.csv")
  """
  # Read the CSV file into a temporary dataframe
  try:
    temp_df = pd.read_csv(csv_file)
  except FileNotFoundError:
    print(f"Error: CSV file '{csv_file}' not found.")
    return

  # Print the first 10 rows (or all rows if less than 10)
  if len(temp_df) < 10:
    print(temp_df)
  else:
    print(temp_df.head(10))

# Example usage
process_downloaded_videos()
# Out:
#      video_id                  video_path  \
# 0    21179416    videos_1000\21179416.mp4
# 1     5629184     videos_1000\5629184.mp4
# 2  1063125190  videos_1000\1063125190.mp4
# 3  1039695998  videos_1000\1039695998.mp4
# 4     9607838     videos_1000\9607838.mp4
# 5    21157780    videos_1000\21157780.mp4
# 6  1016180245  videos_1000\1016180245.mp4
# 7    19107358    videos_1000\19107358.mp4
# 8  1036840850  videos_1000\1036840850.mp4
# 9    13347398    videos_1000\13347398.mp4
#
#                                          description
# 0                          Aerial shot winter forest
# 1  Senior couple looking through binoculars on sa...
# 2  A beautiful cookie with oranges lies on a gree...
# 3  Japanese highrise office skyscrapers tokyo square
# 4  Zrenjanin,serbia march 21 2015: fans watching ...
# 5     Young beautiful woman using smartphone in cafe
# 6  3d render of inky injections into water with l...
# 7  Swimming in the pool ,slow motion 120 fps,hand...
# 8  Circa 1940s usa:  woman posing for camera next...
# 9                    Timor-leste scanned by software

# %%
import csv


def fix_csv_empty_rows(csv_file="downloaded_videos.csv", output_file="fixed_downloaded_videos.csv"):
  """
  Reads a CSV file with empty rows and writes a new file without empty rows.

  Args:
    csv_file: The path to the CSV file with empty rows. (default: "downloaded_videos.csv")
    output_file: The path to the output CSV file without empty rows. (default: "fixed_downloaded_videos.csv")
  """
  # Open the input CSV file for reading
  with open(csv_file, "r", encoding="utf-8") as infile, open(output_file, "w", newline="", encoding="latin-1") as outfile:
    reader = csv.reader(infile)
    writer = csv.writer(outfile)

    # Write header row if it exists
    try:
      header = next(reader)
      writer.writerow(header)
    except StopIteration:  # Handle empty file case
      pass

    # Write non-empty rows to the output file
    for row in reader:
      if row:  # Check if the row is not empty
        writer.writerow(row)

  print(f"Fixed CSV file written to: {output_file}")


# Example usage
fix_csv_empty_rows()
# Out:
# Fixed CSV file written to: fixed_downloaded_videos.csv

# %%
import os
import csv


def verify_downloaded_videos(download_folder="videos_1000", csv_file="fixed_downloaded_videos.csv"):
  """
  Verifies if all videos in the download folder have a corresponding entry in the CSV file.

  Args:
    download_folder: The path to the folder containing downloaded videos. (default: "videos_1000")
    csv_file: The path to the CSV file containing video data. (default: "fixed_downloaded_videos.csv")
  """
  # Get a list of video filenames from the download folder
  video_files = [f for f in os.listdir(download_folder) if os.path.isfile(os.path.join(download_folder, f))]

  # Set to store video IDs found in the CSV
  video_ids_in_csv = set()

  # Open the CSV file for reading
  try:
    with open(csv_file, "r", encoding="utf-8") as csvfile:
      reader = csv.reader(csvfile)
      next(reader, None)  # Skip the header row
      for row in reader:
        video_id = row[0]  # Assuming video ID is the first column
        video_ids_in_csv.add(video_id)
  except FileNotFoundError:
    print(f"Error: CSV file '{csv_file}' not found.")
    return
  except UnicodeDecodeError:
    print(f"Error: Unable to decode CSV file '{csv_file}' using UTF-8. Consider using a different encoding.")
    return

  # Find missing videos (not in CSV but present in folder)
  missing_videos = [f.split(".")[0] for f in video_files if f.split(".")[0] not in video_ids_in_csv]

  # Print results
  if missing_videos:
    print(f"Missing video entries in CSV:")
    for video in missing_videos:
      print(f"- {video}")
  else:
    print(f"All videos in '{download_folder}' have corresponding entries in '{csv_file}'.")


# Verify downloaded videos
verify_downloaded_videos()
# Out:
# All videos in 'videos_1000' have corresponding entries in 'fixed_downloaded_videos.csv'.
