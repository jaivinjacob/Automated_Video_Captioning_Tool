# %%
import pandas as pd

# Load the CSV file
data = pd.read_csv('test_videodata_description.csv')

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration
import torch
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm

# Load the tokenizer and model
t5_tokenizer = T5Tokenizer.from_pretrained('./T5_Trained')
t5_model = T5ForConditionalGeneration.from_pretrained('./T5_Trained').to('cuda')

# Define a custom Dataset class
class VideoDescriptionDataset(Dataset):
    def __init__(self, data, tokenizer, max_length=128):
        self.data = data
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        inputs = self.tokenizer(
            row['generated_description'], max_length=self.max_length, padding='max_length', truncation=True, return_tensors='pt'
        )
        return {key: val.squeeze(0) for key, val in inputs.items()}

# Initialize dataset and dataloader
t5_dataset = VideoDescriptionDataset(data, t5_tokenizer)
t5_dataloader = DataLoader(t5_dataset, batch_size=4, shuffle=False)

# Generate summaries
t5_model.eval()
t5_summaries = []

for batch in tqdm(t5_dataloader, desc="Generating T5 Summaries"):
    input_ids = batch['input_ids'].to('cuda')
    attention_mask = batch['attention_mask'].to('cuda')
    with torch.no_grad():
        outputs = t5_model.generate(input_ids, attention_mask=attention_mask)
    t5_summaries.extend(t5_tokenizer.batch_decode(outputs, skip_special_tokens=True))

# Add the summaries to the dataframe
data['t5_summary'] = t5_summaries
# Out:
# Generating T5 Summaries:   0%|          | 0/25 [00:00<?, ?it/s]C:\Users\jaivi\anaconda3\envs\tf-gpunew\lib\site-packages\transformers\generation\utils.py:1353: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Generating T5 Summaries:   4%|▍         | 1/25 [00:07<03:01,  7.57s/it]C:\Users\jaivi\anaconda3\envs\tf-gpunew\lib\site-packages\transformers\generation\utils.py:1353: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Generating T5 Summaries: 100%|██████████| 25/25 [00:13<00:00,  1.86it/s]

# %%
import torch
import gc

def clear_gpu_memory():
    torch.cuda.empty_cache()
    gc.collect()
import gc

def clear_ram_memory():
    gc.collect()

# %%
import pandas as pd
from transformers import BartTokenizer, BartForConditionalGeneration
import torch
from tqdm import tqdm

# Load the tokenizer and model
bart_tokenizer = BartTokenizer.from_pretrained('./saved_model')
bart_model = BartForConditionalGeneration.from_pretrained('./saved_model').to('cuda')

# Define the generate_summary function with batch processing, mixed precision, and clearing cache
def generate_summary(texts, batch_size=2):
    bart_model.eval()
    summaries = []
    for i in tqdm(range(0, len(texts), batch_size), desc="Generating Summaries"):
        batch_texts = texts[i:i + batch_size]
        inputs = bart_tokenizer(batch_texts, return_tensors='pt', padding=True, truncation=True).to('cuda')
        torch.cuda.empty_cache()  # Clear the cache
        with torch.no_grad():
            with torch.cuda.amp.autocast():
                outputs = bart_model.generate(**inputs)
        batch_summaries = bart_tokenizer.batch_decode(outputs, skip_special_tokens=True)
        summaries.extend(batch_summaries)
    return summaries

# Generate summaries in smaller batches with mixed precision and cache clearing
bart_summaries = generate_summary(data['generated_description'].tolist(), batch_size=2)

# Add the summaries to the dataframe
data['bart_summary'] = bart_summaries

# Save the results to a new CSV file
data.to_csv('summarized_videodata.csv', index=False)
# Out:
# Generating Summaries:   0%|          | 0/50 [00:00<?, ?it/s]C:\Users\jaivi\anaconda3\envs\tf-gpunew\lib\site-packages\transformers\generation\utils.py:1353: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Generating Summaries: 100%|██████████| 50/50 [00:27<00:00,  1.79it/s]

# %%
# Remove the "generated_description" column
data = data.drop(columns=['generated_description'])

# Save the results to a new CSV file
data.to_csv('model_comparison.csv', index=False)

# %%
data
# Out:
#       video_id                                        description  \
# 0   1006792915  Process of serving margarita cocktail. bartend...
# 1   1007017096  Dolly shot of cook at the kitchen cutting mush...
# 2   1007829319            Small boy feeding pigeons on the street
# 3   1008414787  Aerial view beachfront destination usa picnic ...
# 4   1010428679  Aerial view dubrovnik old town in dalmatia, cr...
# ..         ...                                                ...
# 95     8096140          Moose in autumn - sweden - rutting season
# 96     8800768  Hong kong - circa october 2014: day light city...
# 97     9138830  Circa 1960s - the japanese navy is welcomed to...
# 98     9256856  San pablo city, laguna, philippines - january ...
# 99     9334109  Philadelphia - sep 02, 2014: several people ge...
#
#                                            t5_summary  \
# 0                       Close up of a glass of vodka.
# 1          Cute sourdough sourdough on a wooden table
# 2   Little boy in red jacket and red pants is feed...
# 3   Aerial view of a small island in the mediterra...
# 4                Aerial view of kosteli town, croatia
# ..                                                ...
# 95                          White moose in the forest
# 96  Hong hong kong - june 15, 2019: hong kong city...
# 97            Aerial view of a ship docking in a port
# 98  Aerial view of people dancing in a red and yel...
# 99                             Fountain in ohio, uhio
#
#                                          bart_summary
# 0   Close-up shot of bartender pouring cocktail in...
# 1   Close-up shot of chef cutting mushrooms on a w...
# 2              Little boy feeding pigeons in the park
# 3   Aerial view of a small island in the middle of...
# 4    Aerial view of the old town of kosteler, greece.
# ..                                                ...
# 95                       Mountain moose in the forest
# 96     Hong kong, thailand - september 16, 2018: hong
# 97  Circa 1940s - the first world war was held in ...
# 98  Shanghai, china - september 16, 2018: people i...
# 99  Aerial view of the fountain in the center of t...
#
# [100 rows x 4 columns]

# %% [markdown]
# #### Model Scoring

# %%
# Set display options to show all content without clipping
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#       video_id  \
# 0   1006792915
# 1   1007017096
# 2   1007829319
# 3   1008414787
# 4   1010428679
# 5   1011212219
# 6   1011773219
# 7   1012764110
# 8   1013564174
# 9   1017093517
# 10  1017514603
# 11  1018200826
# 12  1020794734
# 13  1023226984
# 14     1023661
# 15  1024534430
# 16  1024910222
# 17  1025147228
# 18  1027337333
# 19  1029554369
# 20  1029766043
# 21  1030256456
# 22  1031350202
# 23  1031557928
# 24    10329590
# 25  1035171251
# 26  1035435515
# 27  1035833600
# 28  1035887006
# 29  1036618454
# 30  1036855580
# 31  1036962317
# 32  1037935466
# 33  1038306578
# 34  1038885401
# 35  1041051368
# 36  1042576798
# 37  1043520496
# 38  1044327088
# 39    10457660
# 40  1046843575
# 41  1048305190
# 42  1049754361
# 43  1051247458
# 44  1053337022
# 45  1054026800
# 46  1054414568
# 47  1055611901
# 48  1057303213
# 49  1057316200
# 50  1057717990
# 51  1058891284
# 52  1059794264
# 53  1067358689
# 54    11679383
# 55    12901073
# 56    14542579
# 57     1584661
# 58    16378486
# 59     1641709
# 60    17233177
# 61    17311762
# 62    17445478
# 63    18462610
# 64     1950256
# 65     1960231
# 66    20166577
# 67    21550783
# 68    21840349
# 69    23023291
# 70    23076190
# 71     2427971
# 72    25398962
# 73    25515800
# 74    26064674
# 75    28118596
# 76    28247914
# 77    28426018
# 78    29919496
# 79    30196420
# 80    30447421
# 81    31241356
# 82    31350445
# 83    31449142
# 84     3153577
# 85    31544932
# 86     3268106
# 87    33179557
# 88     3364697
# 89     3948206
# 90     4102075
# 91     5016005
# 92     5407643
# 93     7312657
# 94     7873603
# 95     8096140
# 96     8800768
# 97     9138830
# 98     9256856
# 99     9334109
#
#                                                                                                                                                                                                  description  \
# 0                                                                                                              Process of serving margarita cocktail. bartender pouring alcohol drink into a glass close-up.
# 1                                                                                                                                                        Dolly shot of cook at the kitchen cutting mushrooms
# 2                                                                                                                                                                    Small boy feeding pigeons on the street
# 3                                                       Aerial view beachfront destination usa picnic island blvd, tampa, fl 33616. indian rocks beach is a city in pinellas county, florida, united states.
# 4                                       Aerial view dubrovnik old town in dalmatia, croatia - prominent travel destination of croatia. dubrovnik old town was listed as unesco world heritage sites in 1979.
# 5                                                                                                                                                                           Bat-eared fox resting on ground.
# 6                                           Side view of a giant sci-fi interplanetary spaceship flying on neptune background, 3d animation. texture of planet was created in graphic editor without photos.
# 7                                                                                                                                                                 Bartender is stirring cocktails on the bar
# 8                                                                                                                                                                       Business people working hd animation
# 9                                                                                                         Felodipine - male doctor with mobile phone opens and touches hologram active ingrident of medicine
# 10                                                                                              Tokyo, japan - october 8th, 2018. first person point of view hyperlapse clip of walking in the ginza street.
# 11                                                                                                                                                   Sexy blond female posing for a camera on the wild beach
# 12                                                                                                                                                          Lassen volcanic national park sulphur works area
# 13   Man stands on the peak on stone rock in portugal sierra de estrella park and watching to sunset. beautiful moment the miracle of nature. misty valley. man hike.person silhouette stand.foggy mountains
# 14                                                                                                                          Young chinese call center businesswoman at her desk wearing a telephone headset
# 15                                                                                                                      Child at sunset in the meadow. children's crying. spoiled mood. childhood depression
# 16                                                                                                                                   Children's creativity. child girl sculpts from plasticine at the table.
# 17                                                                                   Young active caucasian male and female heli hikers viewing the extreme terrain around them in summer canada red monstro
# 35                                    A woman in a park is holding a baby statue.
# 36                         Barcelona, spain - june 20, 2019: float in the city of
# 37                                                Young girl playing on the beach
# 38                                       Close up of a woman's hand with a knife.
# 39                            Aerial view of a swiss swing on the lake at sunset.
# 40                                               Trains in the city of santa rico
# 41        Two young men sitting at the desk with papers and laptops in the office
# 42                            Moscow, russia - june 15, 2019: the ukraine museum,
# 43                                    Aerial view of a cat in a white background.
# 44                                                 Woman pouring water in a glass
# 45                                A man in armor is throwing a sword and a shield
# 46                             Two people in the office looking out of the window
# 47                                                  Light emier with a long tail.
# 48                                 Two young girls are reading books in the park.
# 49                                          Cute squirt of meat on a wooden board
# 50                                          Aerial view of the beach and the sea.
# 51                                The ruins of the ancient city of kharti, kharti
# 52                                                   Abstract swiss - a swiss - a
# 53                                        Close up of a syringe in a blue t-shirt
# 54                                                      Young couple in a hot tub
# 55          Portrait of a beautiful woman in a white dress holding a wedding ring
# 56    Moscow, russia - june 15, 2019: people walking through the subway tunnel in
# 57                                       Abstract background with a lot of light.
# 58                            Close up of a person with a smear pill in the hand.
# 59                                     Aerial view of a field with white flowers.
# 60                                               Aerial view of a field of wheat.
# 61                                    A man walks in the store and says 'la gita'
# 62                                                Friends drinking beer in a bar.
# 63                                                     Family walking in the park
# 64                               Business people working on laptops in the office
# 65                                    Aerial view of a mountain range in a desert
# 66                                           Aerial view of a road in the forest.
# 67  Aerial view of a large building with many windows and a lot of people walking
# 68                                              Water bottles with ice in a glass
# 69                                          Aerial view of a small town in a city
# 70                   Close up of a young man in a suit and tie sitting on a couch
# 71                                                         Peanuts in the kitchen
# 72                           Young woman sitting on the couch in the living room.
# 73                                                A man is making a chocolate bag
# 74                                                  Chicken sneezing in the grass
# 75                                   New york, nyc - june 20, 2019: gays march in
# 76                                                            Sunset at the beach
# 77                                           Young woman dancing in the nightclub
# 78                                                Bride and groom walking in park
# 79                                                Close up of a knife on a table.
# 80        Aerial view of tourists walking on the cliffs of the atlas mountains in
# 81       Aerial view of a mountain valley with a beautiful view of the mountains.
# 82                                                             The hoot of a hoot
# 83        Beautiful woman sitting on a pier with a green scarf and a towel on her
# 84                        A man is mixing a bowl of roasted red onions in a bowl.
# 85                                              Aerial view of a boat in the sea.
# 86                                               Aerial view of the city at night
# 87                                           Beautiful couple kissing in the park
# 88                                                Close up of a gunman in a mask.
# 89                                               Young woman talking on the phone
# 90                                     Aerial view of the sao paulo church in sao
# 91                   Aerial view of the river in the middle of the san francisco,
# 92             The sand of the sea at sunset. people flying kites on the beach at
# 93                       Mumbai, india - april 20, 2019: a train is seen at night
# 94   Young businessman sitting on bed in the dark with a green light on his face.
# 95                                                      White moose in the forest
# 96                         Hong hong kong - june 15, 2019: hong kong city streets
# 97                                        Aerial view of a ship docking in a port
# 98                     Aerial view of people dancing in a red and yellow costume.
# 99                                                         Fountain in ohio, uhio
#
#                                                                             bart_summary
# 0                                 Close-up shot of bartender pouring cocktail into glass
# 1                      Close-up shot of chef cutting mushrooms on a wooden cutting board
# 2                                                 Little boy feeding pigeons in the park
# 3                                 Aerial view of a small island in the middle of the sea
# 4                                       Aerial view of the old town of kosteler, greece.
# 5                                                                   Kangaroo in the wild
# 6                                                                 Space station in space
# 7                                                Bartender pouring a cocktail in a glass
# 8                                           Businessman talking to a woman at the office
# 9                                                    Doctor using a tablet in a hospital
# 10                              Tokyo, japan - september 16, 2018: people walking on the
# 11                                    Beautiful young woman in a bikini posing in a tree
# 12                                      Aerial view of a mountain road in the background
# 13                                 Aerial view of a man standing on a mountain at sunset
# 14                                      Young business woman working on laptop in office
# 15                                              Little girl running in a field at sunset
# 16                                         Little girl eating orange juice in high chair
# 17                                           Young man and woman hiking in the mountains
# 18                                  Beautiful young woman jumping on the beach at sunset
# 19                                              Aerial view of the port of bergen, italy
# 20                                            Aerial view of the airport from the window
# 21                                                   Aerial view of palm trees at sunset
# 22                                                         Birds flying over a waterfall
# 23                                                Little girl with her hands on her face
# 24                                                         Burning fire in the fireplace
# 25                                  Aerial view of a rice field in a tropical rainforest
# 26                         Aerial view of a small church in the mountains of switzerland
# 27                                                     A mechanic works on a car engine.
# 28                          Moscow, russia - september 22, 2018: refinery in the city of
# 29                                          A young man plays a saxophone in the street.
# 30                                           Aerial view of people on a boat in the sea.
# 31                                     Young woman using mobile phone in the living room
# 32                                          New york, ukraine - february 16, 2019: new y
# 33        Close-up of a man with glasses looking at a laptop computer and looking at the
# 34                          Silhouette of a young woman holding a tree branch at sunset.
# 35                                             Beautiful woman holding baby in her hands
# 36                                 Barcelona, spain - february 16, 2019: a parade in bar
# 37                                                    Pregnant girl playing on the beach
# 38                                   Young woman using a tablet computer to make a cake.
# 39                                 Aerial view of a swing swinging over a lake at sunset
# 40                        Aerial view of a train passing through a large container yard.
# 41                                    Young man and woman sitting at the table in a cafe
# 42                             Moscow, russia - september 22, 2018: the museum of russia
# 43                           Circa 1960s - a man's hand draws a circle in the shape of a
# 44                                        Close-up of a woman pouring water into a glass
# 45                                 A knight with a sword and a shield in the background.
# 46                  Two business people sitting in the office and looking out the window
# 47                                             Animation of seamless loop. seamless loop
# 48                                                   Two girls reading books in the park
# 49                                                Cutting meat on a wooden cutting board
# 50                                                  Aerial view of the beach and the sea
# 51                      Aerial view of the ruins of the ancient city of kathapuri in the
# 52                                             Animation of seamless loop. seamless loop
# 53                                      Doctor in blue gloves with a syringe in his hand
# 54                                                    Sexy couple kissing in the bathtub
# 55          Beautiful young woman in white wedding dress with a wedding ring in her hand
# 56                            Toronto, ontario, canada, july 2019: subway in toronto can
# 57  Circa 1960s - a futuristic disco disco disco show is being performed in a futuristic
# 58                           Close-up shot of a doctor with a vial in his hand. close up
# 59                               Aerial view of a field with white flowers. aerial view.
# 60                                                 Aerial view of a field of green wheat
# 61                                  Shanghai, china - september 16, 2018: man walking in
# 62                                               Group of friends drinking beer in a bar
# 63                                                        Family running through a field
# 64                               Two business people working together in a modern office
# 65                                         Aerial view of a mountain range in the desert
# 66                                                   Aerial view of a road in the forest
# 67                        Toronto, ontario, canada september 2019: view of the cityscape
# 68                                                             Water pouring into glass
# 69                                   Aerial view of a building in the middle of the city
# 70                                   Businessman in a suit and tie singing in the studio
# 71                                                          Peanut on a white background
# 72    Beautiful young woman sitting on the couch in the living room and using vr headset
# 73                                   Close-up of a man making a chocolate bar. close up.
# 74                                                                 Chickens in the grass
# 75                       Toronto, ontario, canada july 2019: gay people march in toronto
# 76                                                                   Sunset on the beach
# 77                                          Beautiful young woman dancing in a nightclub
# 78                                             Happy bride and groom walking in the park
# 79                                         Close-up of hands cutting bread with a knife.
# 80                             Aerial view of a group of people hiking in the mountains.
# 81                                    Aerial view of a mountain valley in the mountains.
# 82                    Handsome young woman with red hair and blue eyes looking at camera
# 83                      Beautiful young woman sitting on a pier and looking at the ocean
# 84                              Close-up shot of a woman making a salad with red onions.
# 85                                                   Aerial view of a boat in the ocean.
# 86                         Toronto, ontario, canada july 2019: traffic in toronto canada
# 87                                                      Young couple kissing in the park
# 88                                Close up of a man with a gun in a dark room. close up.
# 89                                          Businesswoman talking on the phone in office
# 90                               Venice, italy - november 15, 2019: the cathedral of the
# 91                                      Aerial view of a river in the middle of the city
# 92                                                          Kites on the beach at sunset
# 93                                 Mumbai, india - september 16, 2018: a train passes by
# 94             Portrait of a young man sitting on the bed and reading a book in the dark
# 95                                                          Mountain moose in the forest
# 96                                        Hong kong, thailand - september 16, 2018: hong
# 97                                  Circa 1940s - the first world war was held in 1940s.
# 98                                   Shanghai, china - september 16, 2018: people in red
# 99                                Aerial view of the fountain in the center of the city.

# %% [markdown]
# BLEU Score
#
# The BLEU (Bilingual Evaluation Understudy) score measures the quality of machine-generated translations or text summaries by comparing n-grams (word sequences) in the generated text to those in reference texts, with higher scores indicating greater similarity and relevance.

# %%
import pandas as pd
import nltk
from nltk.translate.bleu_score import sentence_bleu

# Initialize lists to store BLEU scores
t5_bleu_scores = []
bart_bleu_scores = []

# Iterate through each row in the DataFrame
for index, row in data.iterrows():
    reference = row['description'].split()  # Tokenize the reference description
    t5_summary = row['t5_summary'].split()  # Tokenize the T5 summary
    bart_summary = row['bart_summary'].split()  # Tokenize the BART summary

    # Calculate BLEU score for T5 summary
    t5_bleu = sentence_bleu([reference], t5_summary)
    t5_bleu_scores.append(t5_bleu)

    # Calculate BLEU score for BART summary
    bart_bleu = sentence_bleu([reference], bart_summary)
    bart_bleu_scores.append(bart_bleu)

# Add BLEU scores to the DataFrame
data['t5_bleu'] = t5_bleu_scores
data['bart_bleu'] = bart_bleu_scores

# Calculate average BLEU scores
average_t5_bleu = sum(t5_bleu_scores) / len(t5_bleu_scores)
average_bart_bleu = sum(bart_bleu_scores) / len(bart_bleu_scores)

# Print average BLEU scores
print(f'Average BLEU score for T5 model: {average_t5_bleu:.4f}')
print(f'Average BLEU score for BART model: {average_bart_bleu:.4f}')

# Save the DataFrame with BLEU scores to a new CSV file
output_file_path = 'output_with_bleu_scores.csv'
data.to_csv(output_file_path, index=False)

print("BLEU scores calculated and saved to", output_file_path)
# Out:
# Average BLEU score for T5 model: 0.0068
# Average BLEU score for BART model: 0.0000
# BLEU scores calculated and saved to output_with_bleu_scores.csv
# C:\Users\jaivi\anaconda3\envs\tf-gpunew\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\jaivi\anaconda3\envs\tf-gpunew\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# C:\Users\jaivi\anaconda3\envs\tf-gpunew\lib\site-packages\nltk\translate\bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %% [markdown]
# ROUGE Score
#
# ROUGE scores evaluate the quality of generated summaries by measuring the overlap of n-grams (words or sequences of words) between the generated and reference summaries, with ROUGE-1 focusing on unigrams, ROUGE-2 on bigrams, and ROUGE-3 on trigrams.

# %%
import pandas as pd
from rouge_score import rouge_scorer

# Initialize ROUGE scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# Initialize lists to store ROUGE scores
t5_rouge_scores = []
bart_rouge_scores = []

# Iterate through each row in the DataFrame
for index, row in data.iterrows():
    reference = row['description']  # Reference description
    t5_summary = row['t5_summary']  # T5 summary
    bart_summary = row['bart_summary']  # BART summary

    # Calculate ROUGE score for T5 summary
    t5_rouge = scorer.score(reference, t5_summary)
    t5_rouge_scores.append(t5_rouge)

    # Calculate ROUGE score for BART summary
    bart_rouge = scorer.score(reference, bart_summary)
    bart_rouge_scores.append(bart_rouge)

# Calculate average ROUGE scores
def average_rouge_scores(rouge_scores, metric):
    precision = sum(score[metric].precision for score in rouge_scores) / len(rouge_scores)
    recall = sum(score[metric].recall for score in rouge_scores) / len(rouge_scores)
    fmeasure = sum(score[metric].fmeasure for score in rouge_scores) / len(rouge_scores)
    return precision, recall, fmeasure

average_t5_rouge1 = average_rouge_scores(t5_rouge_scores, 'rouge1')
average_t5_rouge2 = average_rouge_scores(t5_rouge_scores, 'rouge2')
average_t5_rougeL = average_rouge_scores(t5_rouge_scores, 'rougeL')

average_bart_rouge1 = average_rouge_scores(bart_rouge_scores, 'rouge1')
average_bart_rouge2 = average_rouge_scores(bart_rouge_scores, 'rouge2')
average_bart_rougeL = average_rouge_scores(bart_rouge_scores, 'rougeL')

# Print average ROUGE scores
print('Average ROUGE scores for T5 model:')
print(f'ROUGE-1: Precision={average_t5_rouge1[0]:.4f}, Recall={average_t5_rouge1[1]:.4f}, F-measure={average_t5_rouge1[2]:.4f}')
print(f'ROUGE-2: Precision={average_t5_rouge2[0]:.4f}, Recall={average_t5_rouge2[1]:.4f}, F-measure={average_t5_rouge2[2]:.4f}')
print(f'ROUGE-L: Precision={average_t5_rougeL[0]:.4f}, Recall={average_t5_rougeL[1]:.4f}, F-measure={average_t5_rougeL[2]:.4f}')

print('Average ROUGE scores for BART model:')
print(f'ROUGE-1: Precision={average_bart_rouge1[0]:.4f}, Recall={average_bart_rouge1[1]:.4f}, F-measure={average_bart_rouge1[2]:.4f}')
print(f'ROUGE-2: Precision={average_bart_rouge2[0]:.4f}, Recall={average_bart_rouge2[1]:.4f}, F-measure={average_bart_rouge2[2]:.4f}')
print(f'ROUGE-L: Precision={average_bart_rougeL[0]:.4f}, Recall={average_bart_rougeL[1]:.4f}, F-measure={average_bart_rougeL[2]:.4f}')
# Out:
# Average ROUGE scores for T5 model:
# ROUGE-1: Precision=0.3132, Recall=0.1964, F-measure=0.2234
# ROUGE-2: Precision=0.0871, Recall=0.0589, F-measure=0.0644
# ROUGE-L: Precision=0.2712, Recall=0.1722, F-measure=0.1944
# Average ROUGE scores for BART model:
# ROUGE-1: Precision=0.3093, Recall=0.2086, F-measure=0.2300
# ROUGE-2: Precision=0.0728, Recall=0.0528, F-measure=0.0557
# ROUGE-L: Precision=0.2678, Recall=0.1840, F-measure=0.2002

# %%
import pandas as pd
from bert_score import score

# Convert DataFrame columns to lists
references = data['description'].tolist()
t5_summaries = data['t5_summary'].tolist()
bart_summaries = data['bart_summary'].tolist()

# Calculate BERTScore for T5 summaries
P_t5, R_t5, F1_t5 = score(t5_summaries, references, lang='en', verbose=True)

# Calculate BERTScore for BART summaries
P_bart, R_bart, F1_bart = score(bart_summaries, references, lang='en', verbose=True)

# Print average scores
print("T5 Summaries BERTScore:")
print("Precision:", P_t5.mean().item())
print("Recall:", R_t5.mean().item())
print("F1 Score:", F1_t5.mean().item())

print("\nBART Summaries BERTScore:")
print("Precision:", P_bart.mean().item())
print("Recall:", R_bart.mean().item())
print("F1 Score:", F1_bart.mean().item())
# Out:
# C:\Users\jaivi\anaconda3\envs\tf-gpunew\lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# C:\Users\jaivi\anaconda3\envs\tf-gpunew\lib\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\jaivi\.cache\huggingface\hub\models--roberta-large. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/4 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 10.74 seconds, 9.31 sentences/sec
# Some weights of the model checkpoint at roberta-large were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/4 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/2 [00:00<?, ?it/s]
# done in 12.77 seconds, 7.83 sentences/sec
# T5 Summaries BERTScore:
# Precision: 0.8828864097595215
# Recall: 0.8506925106048584
# F1 Score: 0.8661977648735046
#
# BART Summaries BERTScore:
# Precision: 0.8861337900161743
# Recall: 0.8550518155097961
# F1 Score: 0.8699721693992615
